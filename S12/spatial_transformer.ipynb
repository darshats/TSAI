# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

plt.ion()   # interactive mode

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training dataset
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10(root='.', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])), batch_size=64, shuffle=True, num_workers=4)
# Test dataset
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10(root='.', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    ])), batch_size=64, shuffle=True, num_workers=4)
# Out:
# Files already downloaded and verified

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
#         self.fc1 = nn.Linear(320, 50)
        self.fc1 = nn.Linear(500, 50)
        self.fc2 = nn.Linear(50, 10)

        # Spatial transformer localization-network
        self.localization = nn.Sequential(
#             nn.Conv2d(1, 8, kernel_size=7),
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
        )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(10 * 4 * 4, 32),
            nn.ReLU(True),
            nn.Linear(32, 3 * 2)
        )

        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

    # Spatial transformer network forward function
    def stn(self, x):
#         print(x.size())
        xs = self.localization(x)
#         print(xs.size())
        xs = xs.view(-1, 10 * 4 * 4)
        theta = self.fc_loc(xs)
#         print(theta.size())
        theta = theta.view(-1, 2, 3)

        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)

        return x

    def forward(self, x):
        # transform the input
        x = self.stn(x)

        # Perform the usual forward pass
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
#         x = x.view(-1, 320)
#         print(x.size())
        x = x.view(-1, 500)
#         print(x.size())
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)


model = Net().to(device)

# %%
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 26, 26]           1,184
#          MaxPool2d-2            [-1, 8, 13, 13]               0
#               ReLU-3            [-1, 8, 13, 13]               0
#             Conv2d-4             [-1, 10, 9, 9]           2,010
#          MaxPool2d-5             [-1, 10, 4, 4]               0
#               ReLU-6             [-1, 10, 4, 4]               0
#             Linear-7                   [-1, 32]           5,152
#               ReLU-8                   [-1, 32]               0
#             Linear-9                    [-1, 6]             198
#            Conv2d-10           [-1, 10, 28, 28]             760
#            Conv2d-11           [-1, 20, 10, 10]           5,020
#         Dropout2d-12           [-1, 20, 10, 10]               0
#            Linear-13                   [-1, 50]          25,050
#            Linear-14                   [-1, 10]             510
# ================================================================
# Total params: 39,884
# Trainable params: 39,884
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.16
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.33
# ----------------------------------------------------------------
# /media/App/anaconda3/envs/NN/lib/python3.9/site-packages/torch/nn/functional.py:4065: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /media/App/anaconda3/envs/NN/lib/python3.9/site-packages/torch/nn/functional.py:4003: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
#         print(data.size(), target.size())

        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 500 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
#
# A simple test procedure to measure STN the performances on CIFAR10.
#


def test():
    with torch.no_grad():
        model.eval()
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)

            # sum up batch loss
            test_loss += F.nll_loss(output, target, size_average=False).item()
            # get the index of the max log-probability
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'
              .format(test_loss, correct, len(test_loader.dataset),
                      100. * correct / len(test_loader.dataset)))

# %%
def convert_image_np(inp):
    """Convert a Tensor to numpy image."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.4914, 0.4822, 0.4465])
    std = np.array([0.2023, 0.1994, 0.2010])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    return inp

# We want to visualize the output of the spatial transformers layer
# after the training, we visualize a batch of input images and
# the corresponding transformed batch using STN.


def visualize_stn():
    with torch.no_grad():
        # Get a batch of training data
        data = next(iter(test_loader))[0].to(device)

        input_tensor = data.cpu()
        transformed_input_tensor = model.stn(data).cpu()

        in_grid = convert_image_np(
            torchvision.utils.make_grid(input_tensor))

        out_grid = convert_image_np(
            torchvision.utils.make_grid(transformed_input_tensor))

        # Plot the results side-by-side
        f, axarr = plt.subplots(1, 2, figsize=(15,15))
        axarr[0].imshow(in_grid)
        axarr[0].set_title('Dataset Images')

        axarr[1].imshow(out_grid)
        axarr[1].set_title('Transformed Images')

for epoch in range(1, 50 + 1):
    train(epoch)
    test()

# Visualize the STN transformation on some input batch
visualize_stn()

plt.ioff()
plt.show()
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.340375
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 2.141888
# /media/App/anaconda3/envs/NN/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Average loss: 1.9583, Accuracy: 3041/10000 (30%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.132876
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 2.003807
#
# Test set: Average loss: 1.7664, Accuracy: 3803/10000 (38%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 2.123543
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 1.719822
#
# Test set: Average loss: 1.6697, Accuracy: 4109/10000 (41%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.686588
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 1.818903
#
# Test set: Average loss: 1.6178, Accuracy: 4188/10000 (42%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.856863
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 1.710658
#
# Test set: Average loss: 1.5472, Accuracy: 4512/10000 (45%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.727242
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 1.633501
#
# Test set: Average loss: 1.5193, Accuracy: 4650/10000 (46%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.622908
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 1.780031
#
# Test set: Average loss: 1.4997, Accuracy: 4659/10000 (47%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.691844
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 1.462509
#
# Test set: Average loss: 1.5116, Accuracy: 4702/10000 (47%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.651123
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 1.761769
#
# Test set: Average loss: 1.4718, Accuracy: 4755/10000 (48%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.703151
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 1.466201
#
# Test set: Average loss: 1.4202, Accuracy: 4960/10000 (50%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.904187
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 1.487566
#
# Test set: Average loss: 1.3931, Accuracy: 5100/10000 (51%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.707105
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 1.518517
#
# Test set: Average loss: 1.3714, Accuracy: 5150/10000 (52%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.664308
# Train Epoch: 13 [32000/50000 (64%)]	Loss: 1.281939
#
# Test set: Average loss: 1.3797, Accuracy: 5052/10000 (51%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.554665
# Train Epoch: 14 [32000/50000 (64%)]	Loss: 1.518355
#
# Test set: Average loss: 1.3711, Accuracy: 5216/10000 (52%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.489968
# Train Epoch: 15 [32000/50000 (64%)]	Loss: 1.501104
#
# Test set: Average loss: 1.3221, Accuracy: 5327/10000 (53%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.251315
# Train Epoch: 16 [32000/50000 (64%)]	Loss: 1.514257
#
# Test set: Average loss: 1.3639, Accuracy: 5275/10000 (53%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.585410
# Train Epoch: 17 [32000/50000 (64%)]	Loss: 1.452763
#
# Test set: Average loss: 1.3176, Accuracy: 5352/10000 (54%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.491103
# Train Epoch: 18 [32000/50000 (64%)]	Loss: 1.609998
#
# Test set: Average loss: 1.3055, Accuracy: 5392/10000 (54%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.327497
# Train Epoch: 19 [32000/50000 (64%)]	Loss: 1.360127
#
# Test set: Average loss: 1.3074, Accuracy: 5416/10000 (54%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.536333
# Train Epoch: 20 [32000/50000 (64%)]	Loss: 1.356449
#
# Test set: Average loss: 1.2823, Accuracy: 5524/10000 (55%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.627769
# Train Epoch: 21 [32000/50000 (64%)]	Loss: 1.576946
#
# Test set: Average loss: 1.2968, Accuracy: 5437/10000 (54%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.453807
# Train Epoch: 22 [32000/50000 (64%)]	Loss: 1.455267
#
# Test set: Average loss: 1.3235, Accuracy: 5231/10000 (52%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.742197
# Train Epoch: 23 [32000/50000 (64%)]	Loss: 1.419149
#
# Test set: Average loss: 1.2543, Accuracy: 5562/10000 (56%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.451026
# Train Epoch: 24 [32000/50000 (64%)]	Loss: 1.471542
#
# Test set: Average loss: 1.2648, Accuracy: 5593/10000 (56%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.470806
# Train Epoch: 25 [32000/50000 (64%)]	Loss: 1.684016
#
# Test set: Average loss: 1.2789, Accuracy: 5521/10000 (55%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.536017
# Train Epoch: 26 [32000/50000 (64%)]	Loss: 1.664400
#
# Test set: Average loss: 1.2280, Accuracy: 5759/10000 (58%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 1.391263
# Train Epoch: 27 [32000/50000 (64%)]	Loss: 1.551950
#
# Test set: Average loss: 1.2672, Accuracy: 5551/10000 (56%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 1.346368
# Train Epoch: 28 [32000/50000 (64%)]	Loss: 1.417198
#
# Test set: Average loss: 1.2785, Accuracy: 5536/10000 (55%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 1.392832
# Train Epoch: 29 [32000/50000 (64%)]	Loss: 1.173955
#
# Test set: Average loss: 1.2344, Accuracy: 5656/10000 (57%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 1.439338
# Train Epoch: 30 [32000/50000 (64%)]	Loss: 1.397198
#
# Test set: Average loss: 1.2137, Accuracy: 5771/10000 (58%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 1.399344
# Train Epoch: 31 [32000/50000 (64%)]	Loss: 1.532138
#
# Test set: Average loss: 1.2325, Accuracy: 5768/10000 (58%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 1.213331
# Train Epoch: 32 [32000/50000 (64%)]	Loss: 1.575043
#
# Test set: Average loss: 1.2445, Accuracy: 5616/10000 (56%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 1.325401
# Train Epoch: 33 [32000/50000 (64%)]	Loss: 1.556669
#
# Test set: Average loss: 1.2221, Accuracy: 5814/10000 (58%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 1.370785
# Train Epoch: 34 [32000/50000 (64%)]	Loss: 1.442079
#
# Test set: Average loss: 1.2060, Accuracy: 5791/10000 (58%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 1.430066
# Train Epoch: 35 [32000/50000 (64%)]	Loss: 1.525141
#
# Test set: Average loss: 1.2393, Accuracy: 5748/10000 (57%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 1.280013
# Train Epoch: 36 [32000/50000 (64%)]	Loss: 1.565080
#
# Test set: Average loss: 1.3379, Accuracy: 5218/10000 (52%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.421590
# Train Epoch: 37 [32000/50000 (64%)]	Loss: 1.551699
#
# Test set: Average loss: 1.2519, Accuracy: 5597/10000 (56%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 1.295885
# Train Epoch: 38 [32000/50000 (64%)]	Loss: 1.326059
#
# Test set: Average loss: 1.1770, Accuracy: 5888/10000 (59%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 1.231529
# Train Epoch: 39 [32000/50000 (64%)]	Loss: 1.254030
#
# Test set: Average loss: 1.1598, Accuracy: 5951/10000 (60%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 1.467928
# Train Epoch: 40 [32000/50000 (64%)]	Loss: 1.598362
#
# Test set: Average loss: 1.2144, Accuracy: 5853/10000 (59%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 1.185711
# Train Epoch: 41 [32000/50000 (64%)]	Loss: 1.211908
#
# Test set: Average loss: 1.2848, Accuracy: 5507/10000 (55%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 1.536740
# Train Epoch: 42 [32000/50000 (64%)]	Loss: 1.224306
#
# Test set: Average loss: 1.1898, Accuracy: 5856/10000 (59%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 1.375018
# Train Epoch: 43 [32000/50000 (64%)]	Loss: 1.581638
#
# Test set: Average loss: 1.2152, Accuracy: 5745/10000 (57%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 1.398330
# Train Epoch: 44 [32000/50000 (64%)]	Loss: 1.306533
#
# Test set: Average loss: 1.2644, Accuracy: 5583/10000 (56%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 1.468993
# Train Epoch: 45 [32000/50000 (64%)]	Loss: 1.313653
#
# Test set: Average loss: 1.2057, Accuracy: 5723/10000 (57%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 1.295203
# Train Epoch: 46 [32000/50000 (64%)]	Loss: 1.409849
#
# Test set: Average loss: 1.1642, Accuracy: 5996/10000 (60%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.264821
# Train Epoch: 47 [32000/50000 (64%)]	Loss: 1.303128
#
# Test set: Average loss: 1.1514, Accuracy: 6039/10000 (60%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 1.498586
# Train Epoch: 48 [32000/50000 (64%)]	Loss: 1.149325
#
# Test set: Average loss: 1.2878, Accuracy: 5445/10000 (54%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 1.534921
# Train Epoch: 49 [32000/50000 (64%)]	Loss: 1.252161
#
# Test set: Average loss: 1.1806, Accuracy: 5879/10000 (59%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 1.429247
# Train Epoch: 50 [32000/50000 (64%)]	Loss: 1.565229
#
# Test set: Average loss: 1.1822, Accuracy: 5909/10000 (59%)
